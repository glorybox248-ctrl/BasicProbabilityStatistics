# %% [markdown]
# <a href="https://colab.research.google.com/github/glorybox248-ctrl/BasicProbabilityStatistics/blob/main/Colab_%EC%84%B8%EB%B2%88%EC%A7%B8%20%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,2,3,4,5,6,7])
y = np.array([73.2,74.5,75.8,72.1,71.1,68.2,67.7])
plt.plot(x,y,color="b")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,2,3,4,5,6,7])
y = np.array([73.2,74.5,75.8,72.1,71.1,68.2,67.7])
plt.scatter(x,y,color="b")
plt.grid()
plt.show()

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

font_path ="/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
fm.fontManager.addfont(font_path)

plt.rc('font',family=fm.FontProperties(fname=font_path).get_name())

x = np.array(["1월","2월","3월","4월","5월","6월","7월"])
y = np.array([73.2,74.5,75.8,72.1,71.1,68.2,67.7])
plt.plot(x,y,color="b",marker='o')

plt.ylabel("체중(kg)", size=13)
plt.title("월별 체중 변화 그래프")

plt.grid()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-5,5,300)
y1= x**2
y2= (x-2)**2
plt.plot(x,y1,color="b")
plt.plot(x,y2,color="k",linestyle="--")

plt.grid()
plt.show()

# %%
# !apt-get update -qq
# !apt-get install -y fonts-nanum
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

font_path ="/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
fm.fontManager.addfont(font_path)

plt.rc('font',family=fm.FontProperties(fname=font_path).get_name())

plt.rcParams["axes.unicode_minus"]=False
x=np.linspace(-5,5)
y1 = 2*x
y2 = 5*x

plt.plot(x,y1,label="y1 값",color ='r')
plt.plot(x,y2,label="y2 값",linestyle="dashed",color ='k')

plt.xlabel("X-축", size=13)
plt.ylabel("Y-축", size=13)
plt.title("실습 그래프")
plt.grid()
plt.legend()

plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
